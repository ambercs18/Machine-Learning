# %%
print("Enter number of attributes")
n=int(input())

print("Enter attributes")
ar=[x for x in input().split()]

print("Enter number of datasets")
m=int(input())
data=[]
print("Enter the data")
for _ in range(m):    
    a=[x for x in input().split()]
    data.append(a)

print("Enter outcomes")
out=[x for x in input().split()]

ans=["phi"]*m
for i in range(m):
    if out[i]=="yes":
        for j in range(n):
            if ans[j]=="phi":
                ans=data[i]
                break
            else:
                if ans[j]==data[i][j]:
                    continue
                else:
                    ans[j]="?"
print(ans)
# Out:
# Enter number of attributes
# 4
# Enter attributes
# c t f s
# Enter number of datasets
# 5
# Enter the data
# g h n w
# g h y s
# b s n w
# o h n w
# g s y s
# Enter outcomes
# yes n n yes yes
# ['?', '?', '?', '?']
