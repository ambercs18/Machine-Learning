# %%
import pandas as pd
import numpy as np 
print("Data")
data = pd.read_csv("../input/input1/inp.csv")
print(data)


print("Attributes")
#making an array of all the attributes
d = np.array(data)[:,:-1]
print(d)


out = np.array(data)[:,-1]

# print("Enter number of attributes")
# n=int(input())

# print("Enter attributes")
# ar=[x for x in input().split()]

# print("Enter number of datasets")
# m=int(input())
# data=[]
# print("Enter the data")
# for _ in range(m):    
#     a=[x for x in input().split()]
#     data.append(a)

# print("Enter outcomes") ../input/input1/inp.csv
# out=[x for x in input().split()]

n=6
m=3

ans=["phi"]*m
for i in range(m):
    if out[i]=="Yes":
        for j in range(n):
            if ans[j]=="phi":
                ans=d[i]
                break
            else:
                if ans[j]==d[i][j]:
                    continue
                else:
                    ans[j]="?"
print("Output ------>",ans)
# Out:
#    Sunny  Warm Normal  Strong Warm.1    Same  Yes
# 0  Sunny  Warm   High  Strong   Warm    Same  Yes
# 1  Rainy  Cold   High  Strong   Warm  Change   No
# 2  Sunny  Warm   High  Strong   Cool  Change  Yes
# [['Sunny' 'Warm' 'High' 'Strong' 'Warm' 'Same']
#  ['Rainy' 'Cold' 'High' 'Strong' 'Warm' 'Change']
#  ['Sunny' 'Warm' 'High' 'Strong' 'Cool' 'Change']]
# Output ------> ['Sunny' 'Warm' 'High' 'Strong' '?' '?']
